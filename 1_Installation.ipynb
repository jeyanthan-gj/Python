# %% [markdown]
# <a href="https://colab.research.google.com/github/jeyanthan-gj/Python/blob/main/1_Installation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###****Python Installation Guide****

# %% [markdown]
# **What is Python?**
#
# Python is a high-level, interpreted, and easy-to-learn programming language used in:
#
# *   Web Development
# *   Artificial Intelligence and Machine Learning
# *   Data Science and Analytics
# *   Automation and Scripting
# *   Cybersecurity
# *   Game Development
# *   Desktop Applications
# *   Embedded Systems and IoT

# %% [markdown]
# **Step 1: Download Python**

# %% [markdown]
# Visit the official Python website:
#
# [Python](https://www.python.org/downloads)
#
# The website automatically detects your operating system and suggests the latest stable version.

# %% [markdown]
# **Step 2: Install Python on Windows**

# %% [markdown]
# Download Installer
#
# Download the latest Python installer (.exe file).
#
# Example:
#
# python-3.x.x-amd64.exe

# %% [markdown]
# ### **Run the Installer**

# %% [markdown]
# **Double-click the downloaded file.**
#
# You will see the Python Setup window.
#
# **Important**
#
# ✅ Check:
#
# **☑ Add python.exe to PATH**
#
# This is very important because it allows you to run Python from Command Prompt or Terminal.
#
# Then click:
#
# Install Now

# %% [markdown]
# ### **What Happens During Installation?**

# %% [markdown]
# The installer automatically installs:
#
# 1.Python Interpreter
#
# 2.Standard Library
#
# 3.IDLE (Python's built-in editor)
#
# 4.pip (Package Installer)
#
# 5.Documentation and Tools

# %% [markdown]
# ## **Verify Installation**

# %% [markdown]
# Open Command Prompt:
#
# ```
# python --version
# ```
#
# Output:
#
# ```
# Python 3.13.5
# ```
