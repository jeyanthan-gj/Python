# %% [markdown]
# # Python Data Types

# %% [markdown]
# ## What is a Data Type?
#
# In programming, a **data type** specifies the kind of value a variable can store.
#
# Different data types support different operations and behaviors.
#
# Examples:
#
# - Numbers can be added and multiplied.
# - Strings can be concatenated.
# - Lists can store multiple values.
# - Dictionaries store data as key-value pairs.

# %% [markdown]
# ## Built-in Data Types in Python
#
# Python provides several built-in data types grouped into categories.

# %% [markdown]
# | Category | Data Types |
# |----------|------------|
# | Text Type | `str` |
# | Numeric Types | `int`, `float`, `complex` |
# | Sequence Types | `list`, `tuple`, `range` |
# | Mapping Type | `dict` |
# | Set Types | `set`, `frozenset` |
# | Boolean Type | `bool` |
# | Binary Types | `bytes`, `bytearray`, `memoryview` |
# | None Type | `NoneType` |

# %% [markdown]
# # Getting the Data Type

# %% [markdown]
# ## The `type()` Function
#
# You can determine the data type of any object using the `type()` function.

# %%
x = 5
print(type(x))
# Out:
# <class 'int'>

# %% [markdown]
# # Setting the Data Type
#
# In Python, the data type is automatically determined when a value is assigned to a variable.

# %%
x = "Hello World"                     # str
x = 20                                # int
x = 20.5                              # float
x = 1j                                # complex
x = ["apple", "banana", "cherry"]     # list
x = ("apple", "banana", "cherry")     # tuple
x = range(6)                          # range
x = {"name": "John", "age": 36}       # dict
x = {"apple", "banana", "cherry"}     # set
x = frozenset({"apple", "banana", "cherry"})  # frozenset
x = True                              # bool
x = b"Hello"                          # bytes
x = bytearray(5)                      # bytearray
x = memoryview(bytes(5))              # memoryview
x = None                              # NoneType

# %% [markdown]
# # Common Data Types Examples

# %%
name = "John"
age = 25
height = 5.8
is_student = True

print(type(name))
print(type(age))
print(type(height))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# # Setting a Specific Data Type
#
# If you want to explicitly specify the data type, you can use constructor functions.

# %%
x = str("Hello World")                        # str
x = int(20)                                  # int
x = float(20.5)                              # float
x = complex(1j)                              # complex
x = list(("apple", "banana", "cherry"))      # list
x = tuple(("apple", "banana", "cherry"))     # tuple
x = range(6)                                 # range
x = dict(name="John", age=36)                # dict
x = set(("apple", "banana", "cherry"))       # set
x = frozenset(("apple", "banana", "cherry")) # frozenset
x = bool(5)                                  # bool
x = bytes(5)                                 # bytes
x = bytearray(5)                             # bytearray
x = memoryview(bytes(5))                     # memoryview

# %% [markdown]
# ## Examples of Constructor Functions

# %%
a = str(100)
b = int("50")
c = float(10)
d = bool(1)

print(a, type(a))
print(b, type(b))
print(c, type(c))
print(d, type(d))
# Out:
# 100 <class 'str'>
# 50 <class 'int'>
# 10.0 <class 'float'>
# True <class 'bool'>

# %% [markdown]
# # Key Takeaways
#
# - A data type defines the kind of value a variable stores.
# - Python automatically assigns a data type when a value is assigned.
# - Use `type()` to determine the type of an object.
# - Python supports text, numeric, sequence, mapping, set, boolean, binary, and `None` data types.
# - Constructor functions such as `int()`, `float()`, `str()`, and `list()` can explicitly create specific data types.
